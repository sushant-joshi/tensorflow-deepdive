# %% [markdown]
# # Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
train.describe().T
# Out:
#     count        mean        std     min     25%     50%     75%     max
# X1  614.0    0.766906   0.105641    0.62    0.69    0.76    0.86    0.98
# X2  614.0  669.280945  87.825008  514.50  588.00  661.50  735.00  808.50
# X3  614.0  319.417752  44.011299  245.00  294.00  318.50  343.00  416.50
# X4  614.0  174.931596  45.270546  110.25  122.50  147.00  220.50  220.50
# X5  614.0    5.312704   1.750302    3.50    3.50    7.00    7.00    7.00
# X6  614.0    3.509772   1.126169    2.00    2.25    4.00    5.00    5.00
# X7  614.0    0.236401   0.132973    0.00    0.10    0.25    0.40    0.40
# X8  614.0    2.853420   1.556341    0.00    2.00    3.00    4.00    5.00

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 251.2209 - y1_output_loss: 118.6122 - y2_output_loss: 131.4931 - y1_output_root_mean_squared_error: 10.9269 - y2_output_root_mean_squared_error: 11.4815 - val_loss: 72.7124 - val_y1_output_loss: 15.7085 - val_y2_output_loss: 57.7904 - val_y1_output_root_mean_squared_error: 3.9757 - val_y2_output_root_mean_squared_error: 7.5436
# Epoch 2/500
# 614/614 [==============================] - 0s 143us/sample - loss: 35.2607 - y1_output_loss: 13.7654 - y2_output_loss: 21.7331 - y1_output_root_mean_squared_error: 3.6771 - y2_output_root_mean_squared_error: 4.6626 - val_loss: 55.3206 - val_y1_output_loss: 12.5124 - val_y2_output_loss: 42.0954 - val_y1_output_root_mean_squared_error: 3.5515 - val_y2_output_root_mean_squared_error: 6.5351
# Epoch 3/500
# 614/614 [==============================] - 0s 134us/sample - loss: 32.8472 - y1_output_loss: 11.5374 - y2_output_loss: 21.0678 - y1_output_root_mean_squared_error: 3.4077 - y2_output_root_mean_squared_error: 4.6081 - val_loss: 16.8612 - val_y1_output_loss: 6.9297 - val_y2_output_loss: 9.8417 - val_y1_output_root_mean_squared_error: 2.6416 - val_y2_output_root_mean_squared_error: 3.1437
# Epoch 4/500
# 614/614 [==============================] - 0s 141us/sample - loss: 25.4869 - y1_output_loss: 9.9029 - y2_output_loss: 15.5659 - y1_output_root_mean_squared_error: 3.1446 - y2_output_root_mean_squared_error: 3.9495 - val_loss: 21.0003 - val_y1_output_loss: 8.5809 - val_y2_output_loss: 12.1880 - val_y1_output_root_mean_squared_error: 2.9385 - val_y2_output_root_mean_squared_error: 3.5165
# Epoch 5/500
# 614/614 [==============================] - 0s 135us/sample - loss: 27.0233 - y1_output_loss: 10.2008 - y2_output_loss: 16.6274 - y1_output_root_mean_squared_error: 3.2044 - y2_output_root_mean_squared_error: 4.0933 - val_loss: 22.0925 - val_y1_output_loss: 7.2181 - val_y2_output_loss: 14.8053 - val_y1_output_root_mean_squared_error: 2.7023 - val_y2_output_root_mean_squared_error: 3.8458
# Epoch 6/500
# 614/614 [==============================] - 0s 139us/sample - loss: 25.2565 - y1_output_loss: 9.7995 - y2_output_loss: 15.3155 - y1_output_root_mean_squared_error: 3.1346 - y2_output_root_mean_squared_error: 3.9282 - val_loss: 19.1543 - val_y1_output_loss: 7.5941 - val_y2_output_loss: 11.2530 - val_y1_output_root_mean_squared_error: 2.7747 - val_y2_output_root_mean_squared_error: 3.3846
# Epoch 7/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.6526 - y1_output_loss: 8.7734 - y2_output_loss: 13.1242 - y1_output_root_mean_squared_error: 2.9609 - y2_output_root_mean_squared_error: 3.5897 - val_loss: 29.3943 - val_y1_output_loss: 8.6515 - val_y2_output_loss: 20.7118 - val_y1_output_root_mean_squared_error: 2.9497 - val_y2_output_root_mean_squared_error: 4.5490
# Epoch 8/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.6811 - y1_output_loss: 8.7987 - y2_output_loss: 13.6798 - y1_output_root_mean_squared_error: 2.9790 - y2_output_root_mean_squared_error: 3.7158 - val_loss: 15.5484 - val_y1_output_loss: 6.0012 - val_y2_output_loss: 9.4064 - val_y1_output_root_mean_squared_error: 2.4572 - val_y2_output_root_mean_squared_error: 3.0839
# Epoch 9/500
# 614/614 [==============================] - 0s 134us/sample - loss: 22.7078 - y1_output_loss: 8.8645 - y2_output_loss: 13.7531 - y1_output_root_mean_squared_error: 2.9881 - y2_output_root_mean_squared_error: 3.7120 - val_loss: 16.7978 - val_y1_output_loss: 6.4192 - val_y2_output_loss: 10.1571 - val_y1_output_root_mean_squared_error: 2.5511 - val_y2_output_root_mean_squared_error: 3.2078
# Epoch 10/500
# 614/614 [==============================] - 0s 134us/sample - loss: 23.5296 - y1_output_loss: 8.6428 - y2_output_loss: 15.0914 - y1_output_root_mean_squared_error: 2.9380 - y2_output_root_mean_squared_error: 3.8598 - val_loss: 30.0575 - val_y1_output_loss: 7.9710 - val_y2_output_loss: 22.0620 - val_y1_output_root_mean_squared_error: 2.8292 - val_y2_output_root_mean_squared_error: 4.6961
# Epoch 11/500
# 614/614 [==============================] - 0s 140us/sample - loss: 25.5716 - y1_output_loss: 8.9897 - y2_output_loss: 16.6436 - y1_output_root_mean_squared_error: 2.9832 - y2_output_root_mean_squared_error: 4.0832 - val_loss: 42.7771 - val_y1_output_loss: 12.9325 - val_y2_output_loss: 29.7562 - val_y1_output_root_mean_squared_error: 3.5941 - val_y2_output_root_mean_squared_error: 5.4644
# Epoch 12/500
# 614/614 [==============================] - 0s 143us/sample - loss: 21.2172 - y1_output_loss: 8.5417 - y2_output_loss: 12.9385 - y1_output_root_mean_squared_error: 2.9105 - y2_output_root_mean_squared_error: 3.5702 - val_loss: 61.2764 - val_y1_output_loss: 15.6238 - val_y2_output_loss: 45.4666 - val_y1_output_root_mean_squared_error: 3.9647 - val_y2_output_root_mean_squared_error: 6.7497
# Epoch 13/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.1933 - y1_output_loss: 7.7496 - y2_output_loss: 12.5733 - y1_output_root_mean_squared_error: 2.7883 - y2_output_root_mean_squared_error: 3.5240 - val_loss: 30.0411 - val_y1_output_loss: 7.8192 - val_y2_output_loss: 21.9352 - val_y1_output_root_mean_squared_error: 2.8161 - val_y2_output_root_mean_squared_error: 4.7022
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.6351 - y1_output_loss: 7.6202 - y2_output_loss: 11.2037 - y1_output_root_mean_squared_error: 2.7543 - y2_output_root_mean_squared_error: 3.3240 - val_loss: 54.2255 - val_y1_output_loss: 12.2891 - val_y2_output_loss: 41.5679 - val_y1_output_root_mean_squared_error: 3.5221 - val_y2_output_root_mean_squared_error: 6.4668
# Epoch 15/500
# 614/614 [==============================] - 0s 139us/sample - loss: 17.7591 - y1_output_loss: 7.1283 - y2_output_loss: 10.7739 - y1_output_root_mean_squared_error: 2.6604 - y2_output_root_mean_squared_error: 3.2683 - val_loss: 13.8627 - val_y1_output_loss: 5.5716 - val_y2_output_loss: 8.0363 - val_y1_output_root_mean_squared_error: 2.3812 - val_y2_output_root_mean_squared_error: 2.8623
# Epoch 16/500
# 614/614 [==============================] - 0s 137us/sample - loss: 17.4205 - y1_output_loss: 6.6914 - y2_output_loss: 10.6133 - y1_output_root_mean_squared_error: 2.5969 - y2_output_root_mean_squared_error: 3.2675 - val_loss: 14.4775 - val_y1_output_loss: 5.2741 - val_y2_output_loss: 8.8350 - val_y1_output_root_mean_squared_error: 2.3241 - val_y2_output_root_mean_squared_error: 3.0127
# Epoch 17/500
# 614/614 [==============================] - 0s 159us/sample - loss: 16.0952 - y1_output_loss: 6.2382 - y2_output_loss: 9.7152 - y1_output_root_mean_squared_error: 2.5076 - y2_output_root_mean_squared_error: 3.1317 - val_loss: 14.8515 - val_y1_output_loss: 4.9931 - val_y2_output_loss: 9.7951 - val_y1_output_root_mean_squared_error: 2.2406 - val_y2_output_root_mean_squared_error: 3.1354
# Epoch 18/500
# 614/614 [==============================] - 0s 134us/sample - loss: 18.2571 - y1_output_loss: 7.0294 - y2_output_loss: 11.4039 - y1_output_root_mean_squared_error: 2.6498 - y2_output_root_mean_squared_error: 3.3520 - val_loss: 23.2455 - val_y1_output_loss: 6.6376 - val_y2_output_loss: 16.5438 - val_y1_output_root_mean_squared_error: 2.5844 - val_y2_output_root_mean_squared_error: 4.0702
# Epoch 19/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.2807 - y1_output_loss: 5.9168 - y2_output_loss: 10.2447 - y1_output_root_mean_squared_error: 2.4422 - y2_output_root_mean_squared_error: 3.2119 - val_loss: 11.8657 - val_y1_output_loss: 4.7223 - val_y2_output_loss: 6.8938 - val_y1_output_root_mean_squared_error: 2.1954 - val_y2_output_root_mean_squared_error: 2.6545
# Epoch 20/500
# 614/614 [==============================] - 0s 132us/sample - loss: 15.6351 - y1_output_loss: 5.9506 - y2_output_loss: 9.5950 - y1_output_root_mean_squared_error: 2.4400 - y2_output_root_mean_squared_error: 3.1115 - val_loss: 11.5440 - val_y1_output_loss: 4.5422 - val_y2_output_loss: 6.7603 - val_y1_output_root_mean_squared_error: 2.1558 - val_y2_output_root_mean_squared_error: 2.6261
# Epoch 21/500
# 614/614 [==============================] - 0s 133us/sample - loss: 14.0741 - y1_output_loss: 5.5190 - y2_output_loss: 8.4543 - y1_output_root_mean_squared_error: 2.3585 - y2_output_root_mean_squared_error: 2.9175 - val_loss: 10.2790 - val_y1_output_loss: 3.5304 - val_y2_output_loss: 6.4854 - val_y1_output_root_mean_squared_error: 1.9012 - val_y2_output_root_mean_squared_error: 2.5815
# Epoch 22/500
# 614/614 [==============================] - 0s 144us/sample - loss: 12.1361 - y1_output_loss: 5.0725 - y2_output_loss: 7.0734 - y1_output_root_mean_squared_error: 2.2380 - y2_output_root_mean_squared_error: 2.6697 - val_loss: 28.5989 - val_y1_output_loss: 9.9847 - val_y2_output_loss: 18.3159 - val_y1_output_root_mean_squared_error: 3.1768 - val_y2_output_root_mean_squared_error: 4.3019
# Epoch 23/500
# 614/614 [==============================] - 0s 138us/sample - loss: 13.4149 - y1_output_loss: 5.2614 - y2_output_loss: 8.1483 - y1_output_root_mean_squared_error: 2.2895 - y2_output_root_mean_squared_error: 2.8589 - val_loss: 21.2049 - val_y1_output_loss: 6.9420 - val_y2_output_loss: 13.8889 - val_y1_output_root_mean_squared_error: 2.6587 - val_y2_output_root_mean_squared_error: 3.7598
# Epoch 24/500
# 614/614 [==============================] - 0s 136us/sample - loss: 16.2009 - y1_output_loss: 5.6147 - y2_output_loss: 10.4577 - y1_output_root_mean_squared_error: 2.3800 - y2_output_root_mean_squared_error: 3.2460 - val_loss: 11.2156 - val_y1_output_loss: 3.8910 - val_y2_output_loss: 7.1255 - val_y1_output_root_mean_squared_error: 1.9909 - val_y2_output_root_mean_squared_error: 2.6929
# Epoch 25/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.8484 - y1_output_loss: 4.4515 - y2_output_loss: 8.0101 - y1_output_root_mean_squared_error: 2.0821 - y2_output_root_mean_squared_error: 2.7411 - val_loss: 18.5209 - val_y1_output_loss: 4.4280 - val_y2_output_loss: 13.8207 - val_y1_output_root_mean_squared_error: 2.1275 - val_y2_output_root_mean_squared_error: 3.7410
# Epoch 26/500
# 614/614 [==============================] - 0s 141us/sample - loss: 11.3428 - y1_output_loss: 4.3733 - y2_output_loss: 7.1038 - y1_output_root_mean_squared_error: 2.0794 - y2_output_root_mean_squared_error: 2.6493 - val_loss: 19.8232 - val_y1_output_loss: 7.2372 - val_y2_output_loss: 12.3509 - val_y1_output_root_mean_squared_error: 2.7026 - val_y2_output_root_mean_squared_error: 3.5382
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.6312 - y1_output_loss: 4.1145 - y2_output_loss: 6.4951 - y1_output_root_mean_squared_error: 2.0254 - y2_output_root_mean_squared_error: 2.5552 - val_loss: 11.0993 - val_y1_output_loss: 4.0326 - val_y2_output_loss: 7.1441 - val_y1_output_root_mean_squared_error: 1.9901 - val_y2_output_root_mean_squared_error: 2.6719
# Epoch 28/500
# 614/614 [==============================] - 0s 141us/sample - loss: 12.1250 - y1_output_loss: 4.4530 - y2_output_loss: 7.6810 - y1_output_root_mean_squared_error: 2.1037 - y2_output_root_mean_squared_error: 2.7748 - val_loss: 9.0175 - val_y1_output_loss: 3.0320 - val_y2_output_loss: 5.8478 - val_y1_output_root_mean_squared_error: 1.7417 - val_y2_output_root_mean_squared_error: 2.4462
# Epoch 29/500
# 614/614 [==============================] - 0s 156us/sample - loss: 10.5211 - y1_output_loss: 3.9195 - y2_output_loss: 6.6194 - y1_output_root_mean_squared_error: 1.9651 - y2_output_root_mean_squared_error: 2.5806 - val_loss: 10.5010 - val_y1_output_loss: 3.4915 - val_y2_output_loss: 7.0045 - val_y1_output_root_mean_squared_error: 1.8557 - val_y2_output_root_mean_squared_error: 2.6566
# Epoch 30/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.9030 - y1_output_loss: 3.3136 - y2_output_loss: 5.5098 - y1_output_root_mean_squared_error: 1.8289 - y2_output_root_mean_squared_error: 2.3575 - val_loss: 7.9191 - val_y1_output_loss: 2.7185 - val_y2_output_loss: 5.0120 - val_y1_output_root_mean_squared_error: 1.6627 - val_y2_output_root_mean_squared_error: 2.2704
# Epoch 31/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.7397 - y1_output_loss: 3.7662 - y2_output_loss: 6.9354 - y1_output_root_mean_squared_error: 1.9385 - y2_output_root_mean_squared_error: 2.6423 - val_loss: 7.6335 - val_y1_output_loss: 2.3599 - val_y2_output_loss: 5.1486 - val_y1_output_root_mean_squared_error: 1.5432 - val_y2_output_root_mean_squared_error: 2.2917
# Epoch 32/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.5633 - y1_output_loss: 3.5305 - y2_output_loss: 5.9723 - y1_output_root_mean_squared_error: 1.8875 - y2_output_root_mean_squared_error: 2.4496 - val_loss: 17.5748 - val_y1_output_loss: 4.5177 - val_y2_output_loss: 12.7871 - val_y1_output_root_mean_squared_error: 2.1438 - val_y2_output_root_mean_squared_error: 3.6026
# Epoch 33/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.5925 - y1_output_loss: 3.2324 - y2_output_loss: 5.3336 - y1_output_root_mean_squared_error: 1.7956 - y2_output_root_mean_squared_error: 2.3170 - val_loss: 26.3403 - val_y1_output_loss: 8.1336 - val_y2_output_loss: 17.7784 - val_y1_output_root_mean_squared_error: 2.8742 - val_y2_output_root_mean_squared_error: 4.2520
# Epoch 34/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.4255 - y1_output_loss: 3.0892 - y2_output_loss: 5.2849 - y1_output_root_mean_squared_error: 1.7613 - y2_output_root_mean_squared_error: 2.3072 - val_loss: 7.8481 - val_y1_output_loss: 2.6399 - val_y2_output_loss: 5.0212 - val_y1_output_root_mean_squared_error: 1.6355 - val_y2_output_root_mean_squared_error: 2.2744
# Epoch 35/500
# 614/614 [==============================] - 0s 139us/sample - loss: 8.8157 - y1_output_loss: 3.1253 - y2_output_loss: 5.6313 - y1_output_root_mean_squared_error: 1.7731 - y2_output_root_mean_squared_error: 2.3816 - val_loss: 8.4326 - val_y1_output_loss: 2.3066 - val_y2_output_loss: 6.0310 - val_y1_output_root_mean_squared_error: 1.5157 - val_y2_output_root_mean_squared_error: 2.4770
# Epoch 36/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.5127 - y1_output_loss: 3.0712 - y2_output_loss: 5.4492 - y1_output_root_mean_squared_error: 1.7437 - y2_output_root_mean_squared_error: 2.3393 - val_loss: 6.6926 - val_y1_output_loss: 1.9153 - val_y2_output_loss: 4.6060 - val_y1_output_root_mean_squared_error: 1.3991 - val_y2_output_root_mean_squared_error: 2.1760
# Epoch 37/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.1799 - y1_output_loss: 4.3303 - y2_output_loss: 7.8063 - y1_output_root_mean_squared_error: 2.0779 - y2_output_root_mean_squared_error: 2.8040 - val_loss: 8.1039 - val_y1_output_loss: 2.5936 - val_y2_output_loss: 5.4476 - val_y1_output_root_mean_squared_error: 1.6016 - val_y2_output_root_mean_squared_error: 2.3535
# Epoch 38/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.8809 - y1_output_loss: 2.8565 - y2_output_loss: 5.9485 - y1_output_root_mean_squared_error: 1.6974 - y2_output_root_mean_squared_error: 2.4494 - val_loss: 7.1620 - val_y1_output_loss: 2.1376 - val_y2_output_loss: 4.8233 - val_y1_output_root_mean_squared_error: 1.4778 - val_y2_output_root_mean_squared_error: 2.2311
# Epoch 39/500
# 614/614 [==============================] - 0s 136us/sample - loss: 10.4219 - y1_output_loss: 3.2733 - y2_output_loss: 7.0969 - y1_output_root_mean_squared_error: 1.8126 - y2_output_root_mean_squared_error: 2.6714 - val_loss: 7.0216 - val_y1_output_loss: 1.8721 - val_y2_output_loss: 5.0407 - val_y1_output_root_mean_squared_error: 1.3762 - val_y2_output_root_mean_squared_error: 2.2644
# Epoch 40/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.2773 - y1_output_loss: 2.6475 - y2_output_loss: 4.6143 - y1_output_root_mean_squared_error: 1.6309 - y2_output_root_mean_squared_error: 2.1488 - val_loss: 8.7444 - val_y1_output_loss: 2.6688 - val_y2_output_loss: 5.8992 - val_y1_output_root_mean_squared_error: 1.6441 - val_y2_output_root_mean_squared_error: 2.4579
# Epoch 41/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.9309 - y1_output_loss: 2.7765 - y2_output_loss: 6.1113 - y1_output_root_mean_squared_error: 1.6736 - y2_output_root_mean_squared_error: 2.4759 - val_loss: 6.9813 - val_y1_output_loss: 1.7124 - val_y2_output_loss: 5.0919 - val_y1_output_root_mean_squared_error: 1.3202 - val_y2_output_root_mean_squared_error: 2.2887
# Epoch 42/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.2761 - y1_output_loss: 2.4038 - y2_output_loss: 4.9155 - y1_output_root_mean_squared_error: 1.5554 - y2_output_root_mean_squared_error: 2.2038 - val_loss: 8.9806 - val_y1_output_loss: 2.7676 - val_y2_output_loss: 6.0799 - val_y1_output_root_mean_squared_error: 1.6725 - val_y2_output_root_mean_squared_error: 2.4866
# Epoch 43/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.3122 - y1_output_loss: 2.6084 - y2_output_loss: 5.6505 - y1_output_root_mean_squared_error: 1.6179 - y2_output_root_mean_squared_error: 2.3863 - val_loss: 7.5987 - val_y1_output_loss: 2.2273 - val_y2_output_loss: 5.2400 - val_y1_output_root_mean_squared_error: 1.4975 - val_y2_output_root_mean_squared_error: 2.3143
# Epoch 44/500
# 614/614 [==============================] - 0s 144us/sample - loss: 7.0271 - y1_output_loss: 2.2675 - y2_output_loss: 4.7912 - y1_output_root_mean_squared_error: 1.4986 - y2_output_root_mean_squared_error: 2.1866 - val_loss: 13.4677 - val_y1_output_loss: 2.7868 - val_y2_output_loss: 10.4321 - val_y1_output_root_mean_squared_error: 1.6810 - val_y2_output_root_mean_squared_error: 3.2622
# Epoch 45/500
# 614/614 [==============================] - 0s 140us/sample - loss: 10.3800 - y1_output_loss: 3.0409 - y2_output_loss: 7.3608 - y1_output_root_mean_squared_error: 1.7493 - y2_output_root_mean_squared_error: 2.7055 - val_loss: 5.6121 - val_y1_output_loss: 1.6217 - val_y2_output_loss: 3.8783 - val_y1_output_root_mean_squared_error: 1.2805 - val_y2_output_root_mean_squared_error: 1.9931
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.1242 - y1_output_loss: 2.4086 - y2_output_loss: 4.6871 - y1_output_root_mean_squared_error: 1.5587 - y2_output_root_mean_squared_error: 2.1667 - val_loss: 6.5264 - val_y1_output_loss: 1.6450 - val_y2_output_loss: 4.7292 - val_y1_output_root_mean_squared_error: 1.2880 - val_y2_output_root_mean_squared_error: 2.2062
# Epoch 47/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.8433 - y1_output_loss: 2.4455 - y2_output_loss: 5.3649 - y1_output_root_mean_squared_error: 1.5646 - y2_output_root_mean_squared_error: 2.3228 - val_loss: 13.1660 - val_y1_output_loss: 4.0057 - val_y2_output_loss: 8.7936 - val_y1_output_root_mean_squared_error: 2.0281 - val_y2_output_root_mean_squared_error: 3.0088
# Epoch 48/500
# 614/614 [==============================] - 0s 140us/sample - loss: 8.0859 - y1_output_loss: 2.4846 - y2_output_loss: 5.5397 - y1_output_root_mean_squared_error: 1.5806 - y2_output_root_mean_squared_error: 2.3638 - val_loss: 6.3676 - val_y1_output_loss: 2.1782 - val_y2_output_loss: 4.0140 - val_y1_output_root_mean_squared_error: 1.4903 - val_y2_output_root_mean_squared_error: 2.0363
# Epoch 49/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.9966 - y1_output_loss: 2.2892 - y2_output_loss: 4.6636 - y1_output_root_mean_squared_error: 1.5190 - y2_output_root_mean_squared_error: 2.1655 - val_loss: 6.0257 - val_y1_output_loss: 1.7605 - val_y2_output_loss: 4.1401 - val_y1_output_root_mean_squared_error: 1.3344 - val_y2_output_root_mean_squared_error: 2.0604
# Epoch 50/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.3631 - y1_output_loss: 2.1377 - y2_output_loss: 4.1704 - y1_output_root_mean_squared_error: 1.4689 - y2_output_root_mean_squared_error: 2.0508 - val_loss: 8.2304 - val_y1_output_loss: 1.8388 - val_y2_output_loss: 6.2294 - val_y1_output_root_mean_squared_error: 1.3658 - val_y2_output_root_mean_squared_error: 2.5229
# Epoch 51/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.1686 - y1_output_loss: 2.0665 - y2_output_loss: 4.0738 - y1_output_root_mean_squared_error: 1.4413 - y2_output_root_mean_squared_error: 2.0227 - val_loss: 5.3194 - val_y1_output_loss: 1.4668 - val_y2_output_loss: 3.7472 - val_y1_output_root_mean_squared_error: 1.2120 - val_y2_output_root_mean_squared_error: 1.9622
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.6430 - y1_output_loss: 2.1115 - y2_output_loss: 4.5274 - y1_output_root_mean_squared_error: 1.4577 - y2_output_root_mean_squared_error: 2.1256 - val_loss: 6.5753 - val_y1_output_loss: 1.8755 - val_y2_output_loss: 4.5727 - val_y1_output_root_mean_squared_error: 1.3743 - val_y2_output_root_mean_squared_error: 2.1649
# Epoch 53/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.7439 - y1_output_loss: 1.9067 - y2_output_loss: 3.7927 - y1_output_root_mean_squared_error: 1.3854 - y2_output_root_mean_squared_error: 1.9557 - val_loss: 5.5564 - val_y1_output_loss: 1.6391 - val_y2_output_loss: 3.8178 - val_y1_output_root_mean_squared_error: 1.2833 - val_y2_output_root_mean_squared_error: 1.9772
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.9574 - y1_output_loss: 1.8500 - y2_output_loss: 4.0941 - y1_output_root_mean_squared_error: 1.3603 - y2_output_root_mean_squared_error: 2.0266 - val_loss: 6.0148 - val_y1_output_loss: 1.3481 - val_y2_output_loss: 4.5914 - val_y1_output_root_mean_squared_error: 1.1630 - val_y2_output_root_mean_squared_error: 2.1592
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.9385 - y1_output_loss: 1.9121 - y2_output_loss: 4.0351 - y1_output_root_mean_squared_error: 1.3815 - y2_output_root_mean_squared_error: 2.0075 - val_loss: 12.4827 - val_y1_output_loss: 2.3242 - val_y2_output_loss: 9.9017 - val_y1_output_root_mean_squared_error: 1.5368 - val_y2_output_root_mean_squared_error: 3.1813
# Epoch 56/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2571 - y1_output_loss: 1.8747 - y2_output_loss: 4.3388 - y1_output_root_mean_squared_error: 1.3738 - y2_output_root_mean_squared_error: 2.0904 - val_loss: 5.3615 - val_y1_output_loss: 1.4064 - val_y2_output_loss: 3.8349 - val_y1_output_root_mean_squared_error: 1.1882 - val_y2_output_root_mean_squared_error: 1.9874
# Epoch 57/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.5949 - y1_output_loss: 1.7421 - y2_output_loss: 3.8255 - y1_output_root_mean_squared_error: 1.3253 - y2_output_root_mean_squared_error: 1.9592 - val_loss: 7.0996 - val_y1_output_loss: 1.0614 - val_y2_output_loss: 5.9778 - val_y1_output_root_mean_squared_error: 1.0303 - val_y2_output_root_mean_squared_error: 2.4572
# Epoch 58/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.4500 - y1_output_loss: 1.7054 - y2_output_loss: 3.7006 - y1_output_root_mean_squared_error: 1.3104 - y2_output_root_mean_squared_error: 1.9320 - val_loss: 5.4578 - val_y1_output_loss: 2.0062 - val_y2_output_loss: 3.5846 - val_y1_output_root_mean_squared_error: 1.3725 - val_y2_output_root_mean_squared_error: 1.8905
# Epoch 59/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.9949 - y1_output_loss: 1.8496 - y2_output_loss: 4.1167 - y1_output_root_mean_squared_error: 1.3641 - y2_output_root_mean_squared_error: 2.0333 - val_loss: 5.8240 - val_y1_output_loss: 1.6498 - val_y2_output_loss: 4.1345 - val_y1_output_root_mean_squared_error: 1.2738 - val_y2_output_root_mean_squared_error: 2.0498
# Epoch 60/500
# 614/614 [==============================] - 0s 140us/sample - loss: 5.9436 - y1_output_loss: 1.8721 - y2_output_loss: 4.0609 - y1_output_root_mean_squared_error: 1.3614 - y2_output_root_mean_squared_error: 2.0224 - val_loss: 8.0906 - val_y1_output_loss: 2.6637 - val_y2_output_loss: 5.2827 - val_y1_output_root_mean_squared_error: 1.6356 - val_y2_output_root_mean_squared_error: 2.3271
# Epoch 61/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.1012 - y1_output_loss: 1.5617 - y2_output_loss: 3.5000 - y1_output_root_mean_squared_error: 1.2542 - y2_output_root_mean_squared_error: 1.8783 - val_loss: 3.7744 - val_y1_output_loss: 0.9047 - val_y2_output_loss: 2.8242 - val_y1_output_root_mean_squared_error: 0.9473 - val_y2_output_root_mean_squared_error: 1.6962
# Epoch 62/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.9606 - y1_output_loss: 2.3952 - y2_output_loss: 5.5382 - y1_output_root_mean_squared_error: 1.5437 - y2_output_root_mean_squared_error: 2.3617 - val_loss: 3.7769 - val_y1_output_loss: 1.1382 - val_y2_output_loss: 2.6899 - val_y1_output_root_mean_squared_error: 1.0383 - val_y2_output_root_mean_squared_error: 1.6428
# Epoch 63/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.6694 - y1_output_loss: 1.3516 - y2_output_loss: 3.3379 - y1_output_root_mean_squared_error: 1.1518 - y2_output_root_mean_squared_error: 1.8283 - val_loss: 4.6874 - val_y1_output_loss: 1.5601 - val_y2_output_loss: 3.0152 - val_y1_output_root_mean_squared_error: 1.2582 - val_y2_output_root_mean_squared_error: 1.7619
# Epoch 64/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.9047 - y1_output_loss: 1.6373 - y2_output_loss: 4.2397 - y1_output_root_mean_squared_error: 1.2841 - y2_output_root_mean_squared_error: 2.0630 - val_loss: 4.9909 - val_y1_output_loss: 1.5710 - val_y2_output_loss: 3.3064 - val_y1_output_root_mean_squared_error: 1.2598 - val_y2_output_root_mean_squared_error: 1.8450
# Epoch 65/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.4352 - y1_output_loss: 1.1468 - y2_output_loss: 3.2946 - y1_output_root_mean_squared_error: 1.0666 - y2_output_root_mean_squared_error: 1.8159 - val_loss: 3.5658 - val_y1_output_loss: 0.9314 - val_y2_output_loss: 2.5905 - val_y1_output_root_mean_squared_error: 0.9622 - val_y2_output_root_mean_squared_error: 1.6248
# Epoch 66/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.4066 - y1_output_loss: 1.3501 - y2_output_loss: 3.0261 - y1_output_root_mean_squared_error: 1.1645 - y2_output_root_mean_squared_error: 1.7465 - val_loss: 4.7823 - val_y1_output_loss: 1.3233 - val_y2_output_loss: 3.3216 - val_y1_output_root_mean_squared_error: 1.1651 - val_y2_output_root_mean_squared_error: 1.8506
# Epoch 67/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.2841 - y1_output_loss: 3.7553 - y2_output_loss: 6.4598 - y1_output_root_mean_squared_error: 1.9435 - y2_output_root_mean_squared_error: 2.5509 - val_loss: 3.6255 - val_y1_output_loss: 1.0670 - val_y2_output_loss: 2.4753 - val_y1_output_root_mean_squared_error: 1.0439 - val_y2_output_root_mean_squared_error: 1.5924
# Epoch 68/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.9661 - y1_output_loss: 1.1771 - y2_output_loss: 2.8044 - y1_output_root_mean_squared_error: 1.0858 - y2_output_root_mean_squared_error: 1.6695 - val_loss: 5.2712 - val_y1_output_loss: 0.6991 - val_y2_output_loss: 4.4954 - val_y1_output_root_mean_squared_error: 0.8335 - val_y2_output_root_mean_squared_error: 2.1393
# Epoch 69/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.1083 - y1_output_loss: 1.2209 - y2_output_loss: 2.8706 - y1_output_root_mean_squared_error: 1.1099 - y2_output_root_mean_squared_error: 1.6960 - val_loss: 5.3608 - val_y1_output_loss: 1.6979 - val_y2_output_loss: 3.6165 - val_y1_output_root_mean_squared_error: 1.2959 - val_y2_output_root_mean_squared_error: 1.9187
# Epoch 70/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9701 - y1_output_loss: 1.1197 - y2_output_loss: 2.8178 - y1_output_root_mean_squared_error: 1.0620 - y2_output_root_mean_squared_error: 1.6859 - val_loss: 3.2513 - val_y1_output_loss: 0.7998 - val_y2_output_loss: 2.3856 - val_y1_output_root_mean_squared_error: 0.8911 - val_y2_output_root_mean_squared_error: 1.5676
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.9977 - y1_output_loss: 0.9123 - y2_output_loss: 3.0577 - y1_output_root_mean_squared_error: 0.9588 - y2_output_root_mean_squared_error: 1.7545 - val_loss: 2.5641 - val_y1_output_loss: 0.5993 - val_y2_output_loss: 1.9212 - val_y1_output_root_mean_squared_error: 0.7671 - val_y2_output_root_mean_squared_error: 1.4056
# Epoch 72/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3426 - y1_output_loss: 1.2528 - y2_output_loss: 3.0645 - y1_output_root_mean_squared_error: 1.1201 - y2_output_root_mean_squared_error: 1.7573 - val_loss: 2.6833 - val_y1_output_loss: 0.5677 - val_y2_output_loss: 2.0544 - val_y1_output_root_mean_squared_error: 0.7521 - val_y2_output_root_mean_squared_error: 1.4552
# Epoch 73/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.6986 - y1_output_loss: 0.9425 - y2_output_loss: 2.7375 - y1_output_root_mean_squared_error: 0.9727 - y2_output_root_mean_squared_error: 1.6591 - val_loss: 2.7084 - val_y1_output_loss: 0.6276 - val_y2_output_loss: 2.0199 - val_y1_output_root_mean_squared_error: 0.7889 - val_y2_output_root_mean_squared_error: 1.4443
# Epoch 74/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.3569 - y1_output_loss: 0.8769 - y2_output_loss: 2.4751 - y1_output_root_mean_squared_error: 0.9367 - y2_output_root_mean_squared_error: 1.5746 - val_loss: 4.4311 - val_y1_output_loss: 0.7580 - val_y2_output_loss: 3.6509 - val_y1_output_root_mean_squared_error: 0.8637 - val_y2_output_root_mean_squared_error: 1.9197
# Epoch 75/500
# 614/614 [==============================] - 0s 148us/sample - loss: 4.2986 - y1_output_loss: 0.9936 - y2_output_loss: 3.2815 - y1_output_root_mean_squared_error: 0.9965 - y2_output_root_mean_squared_error: 1.8181 - val_loss: 3.3985 - val_y1_output_loss: 1.2042 - val_y2_output_loss: 2.2276 - val_y1_output_root_mean_squared_error: 1.0787 - val_y2_output_root_mean_squared_error: 1.4950
# Epoch 76/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.3755 - y1_output_loss: 0.8772 - y2_output_loss: 2.4746 - y1_output_root_mean_squared_error: 0.9384 - y2_output_root_mean_squared_error: 1.5795 - val_loss: 2.5072 - val_y1_output_loss: 0.6549 - val_y2_output_loss: 1.8256 - val_y1_output_root_mean_squared_error: 0.8057 - val_y2_output_root_mean_squared_error: 1.3631
# Epoch 77/500
# 614/614 [==============================] - 0s 147us/sample - loss: 3.4304 - y1_output_loss: 0.8526 - y2_output_loss: 2.6275 - y1_output_root_mean_squared_error: 0.9208 - y2_output_root_mean_squared_error: 1.6070 - val_loss: 2.3810 - val_y1_output_loss: 0.6483 - val_y2_output_loss: 1.7238 - val_y1_output_root_mean_squared_error: 0.7956 - val_y2_output_root_mean_squared_error: 1.3221
# Epoch 78/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.5699 - y1_output_loss: 0.8299 - y2_output_loss: 2.7439 - y1_output_root_mean_squared_error: 0.9090 - y2_output_root_mean_squared_error: 1.6564 - val_loss: 5.3815 - val_y1_output_loss: 0.6539 - val_y2_output_loss: 4.7453 - val_y1_output_root_mean_squared_error: 0.7963 - val_y2_output_root_mean_squared_error: 2.1788
# Epoch 79/500
# 614/614 [==============================] - 0s 139us/sample - loss: 6.9314 - y1_output_loss: 1.7036 - y2_output_loss: 5.1980 - y1_output_root_mean_squared_error: 1.3078 - y2_output_root_mean_squared_error: 2.2850 - val_loss: 3.2264 - val_y1_output_loss: 0.8831 - val_y2_output_loss: 2.3709 - val_y1_output_root_mean_squared_error: 0.9171 - val_y2_output_root_mean_squared_error: 1.5444
# Epoch 80/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.8148 - y1_output_loss: 0.6348 - y2_output_loss: 2.1560 - y1_output_root_mean_squared_error: 0.7997 - y2_output_root_mean_squared_error: 1.4749 - val_loss: 2.3372 - val_y1_output_loss: 0.6141 - val_y2_output_loss: 1.7049 - val_y1_output_root_mean_squared_error: 0.7724 - val_y2_output_root_mean_squared_error: 1.3193
# Epoch 81/500
# 614/614 [==============================] - 0s 146us/sample - loss: 3.3891 - y1_output_loss: 0.8638 - y2_output_loss: 2.5367 - y1_output_root_mean_squared_error: 0.9309 - y2_output_root_mean_squared_error: 1.5883 - val_loss: 6.3484 - val_y1_output_loss: 0.7542 - val_y2_output_loss: 5.6325 - val_y1_output_root_mean_squared_error: 0.8583 - val_y2_output_root_mean_squared_error: 2.3689
# Epoch 82/500
# 614/614 [==============================] - 0s 179us/sample - loss: 3.5731 - y1_output_loss: 0.9925 - y2_output_loss: 2.5559 - y1_output_root_mean_squared_error: 0.9973 - y2_output_root_mean_squared_error: 1.6058 - val_loss: 4.3913 - val_y1_output_loss: 1.2738 - val_y2_output_loss: 3.1025 - val_y1_output_root_mean_squared_error: 1.1256 - val_y2_output_root_mean_squared_error: 1.7676
# Epoch 83/500
# 614/614 [==============================] - 0s 150us/sample - loss: 3.4383 - y1_output_loss: 0.9268 - y2_output_loss: 2.5378 - y1_output_root_mean_squared_error: 0.9639 - y2_output_root_mean_squared_error: 1.5840 - val_loss: 2.5030 - val_y1_output_loss: 0.6074 - val_y2_output_loss: 1.8529 - val_y1_output_root_mean_squared_error: 0.7780 - val_y2_output_root_mean_squared_error: 1.3776
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.2441 - y1_output_loss: 0.7973 - y2_output_loss: 2.4292 - y1_output_root_mean_squared_error: 0.8961 - y2_output_root_mean_squared_error: 1.5624 - val_loss: 2.3202 - val_y1_output_loss: 0.4594 - val_y2_output_loss: 1.8126 - val_y1_output_root_mean_squared_error: 0.6767 - val_y2_output_root_mean_squared_error: 1.3647
# Epoch 85/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.5374 - y1_output_loss: 0.5378 - y2_output_loss: 1.9949 - y1_output_root_mean_squared_error: 0.7311 - y2_output_root_mean_squared_error: 1.4152 - val_loss: 2.0505 - val_y1_output_loss: 0.5617 - val_y2_output_loss: 1.5003 - val_y1_output_root_mean_squared_error: 0.7278 - val_y2_output_root_mean_squared_error: 1.2332
# Epoch 86/500
# 614/614 [==============================] - 0s 178us/sample - loss: 2.6896 - y1_output_loss: 0.6145 - y2_output_loss: 2.0807 - y1_output_root_mean_squared_error: 0.7830 - y2_output_root_mean_squared_error: 1.4410 - val_loss: 3.2627 - val_y1_output_loss: 0.9080 - val_y2_output_loss: 2.2829 - val_y1_output_root_mean_squared_error: 0.9625 - val_y2_output_root_mean_squared_error: 1.5285
# Epoch 87/500
# 614/614 [==============================] - 0s 144us/sample - loss: 3.4566 - y1_output_loss: 0.8449 - y2_output_loss: 2.5925 - y1_output_root_mean_squared_error: 0.9233 - y2_output_root_mean_squared_error: 1.6138 - val_loss: 1.9140 - val_y1_output_loss: 0.4641 - val_y2_output_loss: 1.4303 - val_y1_output_root_mean_squared_error: 0.6769 - val_y2_output_root_mean_squared_error: 1.2065
# Epoch 88/500
# 614/614 [==============================] - 0s 147us/sample - loss: 7.4232 - y1_output_loss: 2.6503 - y2_output_loss: 4.7232 - y1_output_root_mean_squared_error: 1.6352 - y2_output_root_mean_squared_error: 2.1793 - val_loss: 2.5391 - val_y1_output_loss: 0.7952 - val_y2_output_loss: 1.7003 - val_y1_output_root_mean_squared_error: 0.8874 - val_y2_output_root_mean_squared_error: 1.3235
# Epoch 89/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.4968 - y1_output_loss: 0.8350 - y2_output_loss: 2.6542 - y1_output_root_mean_squared_error: 0.9129 - y2_output_root_mean_squared_error: 1.6320 - val_loss: 2.4343 - val_y1_output_loss: 0.6604 - val_y2_output_loss: 1.7425 - val_y1_output_root_mean_squared_error: 0.8137 - val_y2_output_root_mean_squared_error: 1.3312
# Epoch 90/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.7097 - y1_output_loss: 0.6508 - y2_output_loss: 2.0416 - y1_output_root_mean_squared_error: 0.8098 - y2_output_root_mean_squared_error: 1.4332 - val_loss: 3.1090 - val_y1_output_loss: 0.6711 - val_y2_output_loss: 2.3842 - val_y1_output_root_mean_squared_error: 0.8161 - val_y2_output_root_mean_squared_error: 1.5630
# Epoch 91/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2104 - y1_output_loss: 0.5807 - y2_output_loss: 1.6226 - y1_output_root_mean_squared_error: 0.7615 - y2_output_root_mean_squared_error: 1.2769 - val_loss: 2.9778 - val_y1_output_loss: 0.5253 - val_y2_output_loss: 2.4053 - val_y1_output_root_mean_squared_error: 0.7189 - val_y2_output_root_mean_squared_error: 1.5687
# Epoch 92/500
# 614/614 [==============================] - 0s 145us/sample - loss: 4.0047 - y1_output_loss: 1.0909 - y2_output_loss: 2.8791 - y1_output_root_mean_squared_error: 1.0487 - y2_output_root_mean_squared_error: 1.7044 - val_loss: 2.3851 - val_y1_output_loss: 0.5066 - val_y2_output_loss: 1.8749 - val_y1_output_root_mean_squared_error: 0.6940 - val_y2_output_root_mean_squared_error: 1.3797
# Epoch 93/500
# 614/614 [==============================] - 0s 141us/sample - loss: 2.9549 - y1_output_loss: 0.6735 - y2_output_loss: 2.3005 - y1_output_root_mean_squared_error: 0.8219 - y2_output_root_mean_squared_error: 1.5098 - val_loss: 3.2918 - val_y1_output_loss: 0.4232 - val_y2_output_loss: 2.8928 - val_y1_output_root_mean_squared_error: 0.6256 - val_y2_output_root_mean_squared_error: 1.7031
# Epoch 94/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.9174 - y1_output_loss: 0.6447 - y2_output_loss: 2.2649 - y1_output_root_mean_squared_error: 0.8008 - y2_output_root_mean_squared_error: 1.5087 - val_loss: 4.6803 - val_y1_output_loss: 0.5317 - val_y2_output_loss: 4.2290 - val_y1_output_root_mean_squared_error: 0.6968 - val_y2_output_root_mean_squared_error: 2.0481
# Epoch 95/500
# 614/614 [==============================] - 0s 143us/sample - loss: 2.8130 - y1_output_loss: 0.7358 - y2_output_loss: 2.0661 - y1_output_root_mean_squared_error: 0.8604 - y2_output_root_mean_squared_error: 1.4397 - val_loss: 2.4764 - val_y1_output_loss: 0.6237 - val_y2_output_loss: 1.8122 - val_y1_output_root_mean_squared_error: 0.7900 - val_y2_output_root_mean_squared_error: 1.3610
# Epoch 96/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.3954 - y1_output_loss: 0.6008 - y2_output_loss: 1.7764 - y1_output_root_mean_squared_error: 0.7780 - y2_output_root_mean_squared_error: 1.3380 - val_loss: 2.2576 - val_y1_output_loss: 0.4761 - val_y2_output_loss: 1.7667 - val_y1_output_root_mean_squared_error: 0.6793 - val_y2_output_root_mean_squared_error: 1.3402
# Epoch 97/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.3451 - y1_output_loss: 0.5472 - y2_output_loss: 1.7939 - y1_output_root_mean_squared_error: 0.7402 - y2_output_root_mean_squared_error: 1.3406 - val_loss: 1.7834 - val_y1_output_loss: 0.4656 - val_y2_output_loss: 1.3019 - val_y1_output_root_mean_squared_error: 0.6699 - val_y2_output_root_mean_squared_error: 1.1553
# Epoch 98/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.2920 - y1_output_loss: 0.5295 - y2_output_loss: 1.7581 - y1_output_root_mean_squared_error: 0.7294 - y2_output_root_mean_squared_error: 1.3266 - val_loss: 3.9790 - val_y1_output_loss: 0.5808 - val_y2_output_loss: 3.3925 - val_y1_output_root_mean_squared_error: 0.7528 - val_y2_output_root_mean_squared_error: 1.8472
# Epoch 99/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.0613 - y1_output_loss: 0.7200 - y2_output_loss: 2.3185 - y1_output_root_mean_squared_error: 0.8509 - y2_output_root_mean_squared_error: 1.5288 - val_loss: 2.2143 - val_y1_output_loss: 0.6951 - val_y2_output_loss: 1.5090 - val_y1_output_root_mean_squared_error: 0.8364 - val_y2_output_root_mean_squared_error: 1.2307
# Epoch 100/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.6021 - y1_output_loss: 0.8679 - y2_output_loss: 2.7018 - y1_output_root_mean_squared_error: 0.9355 - y2_output_root_mean_squared_error: 1.6514 - val_loss: 2.0401 - val_y1_output_loss: 0.5229 - val_y2_output_loss: 1.5038 - val_y1_output_root_mean_squared_error: 0.7161 - val_y2_output_root_mean_squared_error: 1.2358
# Epoch 101/500
# 614/614 [==============================] - 0s 159us/sample - loss: 2.7808 - y1_output_loss: 0.7715 - y2_output_loss: 1.9883 - y1_output_root_mean_squared_error: 0.8800 - y2_output_root_mean_squared_error: 1.4165 - val_loss: 2.0420 - val_y1_output_loss: 0.4686 - val_y2_output_loss: 1.6192 - val_y1_output_root_mean_squared_error: 0.6433 - val_y2_output_root_mean_squared_error: 1.2760
# Epoch 102/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.3510 - y1_output_loss: 0.5248 - y2_output_loss: 1.8243 - y1_output_root_mean_squared_error: 0.7262 - y2_output_root_mean_squared_error: 1.3504 - val_loss: 3.3769 - val_y1_output_loss: 0.8249 - val_y2_output_loss: 2.5516 - val_y1_output_root_mean_squared_error: 0.8942 - val_y2_output_root_mean_squared_error: 1.6054
# Epoch 103/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.2461 - y1_output_loss: 0.5036 - y2_output_loss: 1.7476 - y1_output_root_mean_squared_error: 0.7080 - y2_output_root_mean_squared_error: 1.3209 - val_loss: 3.0908 - val_y1_output_loss: 0.7473 - val_y2_output_loss: 2.3189 - val_y1_output_root_mean_squared_error: 0.8572 - val_y2_output_root_mean_squared_error: 1.5349
# Epoch 104/500
# 614/614 [==============================] - 0s 144us/sample - loss: 2.4960 - y1_output_loss: 0.6345 - y2_output_loss: 1.8443 - y1_output_root_mean_squared_error: 0.7973 - y2_output_root_mean_squared_error: 1.3639 - val_loss: 2.3356 - val_y1_output_loss: 0.4668 - val_y2_output_loss: 1.8737 - val_y1_output_root_mean_squared_error: 0.6692 - val_y2_output_root_mean_squared_error: 1.3740
# Epoch 105/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.7247 - y1_output_loss: 0.5583 - y2_output_loss: 2.2586 - y1_output_root_mean_squared_error: 0.7452 - y2_output_root_mean_squared_error: 1.4729 - val_loss: 16.4618 - val_y1_output_loss: 2.6732 - val_y2_output_loss: 13.8667 - val_y1_output_root_mean_squared_error: 1.6201 - val_y2_output_root_mean_squared_error: 3.7198
# Epoch 106/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.1683 - y1_output_loss: 1.2837 - y2_output_loss: 2.8556 - y1_output_root_mean_squared_error: 1.1370 - y2_output_root_mean_squared_error: 1.6957 - val_loss: 7.7034 - val_y1_output_loss: 3.1426 - val_y2_output_loss: 4.4708 - val_y1_output_root_mean_squared_error: 1.7849 - val_y2_output_root_mean_squared_error: 2.1254
# Epoch 107/500
# 614/614 [==============================] - 0s 146us/sample - loss: 2.3400 - y1_output_loss: 0.5781 - y2_output_loss: 1.7456 - y1_output_root_mean_squared_error: 0.7624 - y2_output_root_mean_squared_error: 1.3262 - val_loss: 3.2228 - val_y1_output_loss: 0.7003 - val_y2_output_loss: 2.5660 - val_y1_output_root_mean_squared_error: 0.8199 - val_y2_output_root_mean_squared_error: 1.5971
# Epoch 108/500
# 614/614 [==============================] - 0s 145us/sample - loss: 2.9574 - y1_output_loss: 0.7496 - y2_output_loss: 2.2518 - y1_output_root_mean_squared_error: 0.8655 - y2_output_root_mean_squared_error: 1.4860 - val_loss: 2.5617 - val_y1_output_loss: 1.0368 - val_y2_output_loss: 1.5867 - val_y1_output_root_mean_squared_error: 0.9918 - val_y2_output_root_mean_squared_error: 1.2562
# Epoch 109/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.5762 - y1_output_loss: 0.5226 - y2_output_loss: 2.0579 - y1_output_root_mean_squared_error: 0.7228 - y2_output_root_mean_squared_error: 1.4331 - val_loss: 1.7743 - val_y1_output_loss: 0.4544 - val_y2_output_loss: 1.3375 - val_y1_output_root_mean_squared_error: 0.6467 - val_y2_output_root_mean_squared_error: 1.1645
# Epoch 110/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.2412 - y1_output_loss: 0.4867 - y2_output_loss: 1.7573 - y1_output_root_mean_squared_error: 0.6940 - y2_output_root_mean_squared_error: 1.3265 - val_loss: 1.8300 - val_y1_output_loss: 0.3528 - val_y2_output_loss: 1.4602 - val_y1_output_root_mean_squared_error: 0.5879 - val_y2_output_root_mean_squared_error: 1.2184
# Epoch 111/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.4887 - y1_output_loss: 0.5679 - y2_output_loss: 1.8984 - y1_output_root_mean_squared_error: 0.7572 - y2_output_root_mean_squared_error: 1.3840 - val_loss: 1.9521 - val_y1_output_loss: 0.5410 - val_y2_output_loss: 1.4125 - val_y1_output_root_mean_squared_error: 0.7201 - val_y2_output_root_mean_squared_error: 1.1973
# Epoch 112/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.0717 - y1_output_loss: 0.4607 - y2_output_loss: 1.5979 - y1_output_root_mean_squared_error: 0.6817 - y2_output_root_mean_squared_error: 1.2676 - val_loss: 1.8406 - val_y1_output_loss: 0.3965 - val_y2_output_loss: 1.4482 - val_y1_output_root_mean_squared_error: 0.6146 - val_y2_output_root_mean_squared_error: 1.2095
# Epoch 113/500
# 614/614 [==============================] - 0s 163us/sample - loss: 1.8980 - y1_output_loss: 0.3858 - y2_output_loss: 1.5158 - y1_output_root_mean_squared_error: 0.6226 - y2_output_root_mean_squared_error: 1.2290 - val_loss: 2.1131 - val_y1_output_loss: 0.4100 - val_y2_output_loss: 1.6953 - val_y1_output_root_mean_squared_error: 0.6310 - val_y2_output_root_mean_squared_error: 1.3095
# Epoch 114/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.7745 - y1_output_loss: 0.9202 - y2_output_loss: 2.8265 - y1_output_root_mean_squared_error: 0.9625 - y2_output_root_mean_squared_error: 1.6876 - val_loss: 2.8904 - val_y1_output_loss: 0.7451 - val_y2_output_loss: 2.1179 - val_y1_output_root_mean_squared_error: 0.8561 - val_y2_output_root_mean_squared_error: 1.4689
# Epoch 115/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.0871 - y1_output_loss: 0.5577 - y2_output_loss: 1.5196 - y1_output_root_mean_squared_error: 0.7465 - y2_output_root_mean_squared_error: 1.2369 - val_loss: 1.7355 - val_y1_output_loss: 0.4088 - val_y2_output_loss: 1.3230 - val_y1_output_root_mean_squared_error: 0.6319 - val_y2_output_root_mean_squared_error: 1.1559
# Epoch 116/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.1684 - y1_output_loss: 0.5743 - y2_output_loss: 1.6108 - y1_output_root_mean_squared_error: 0.7556 - y2_output_root_mean_squared_error: 1.2639 - val_loss: 2.2816 - val_y1_output_loss: 0.4389 - val_y2_output_loss: 1.8824 - val_y1_output_root_mean_squared_error: 0.6300 - val_y2_output_root_mean_squared_error: 1.3729
# Epoch 117/500
# 614/614 [==============================] - 0s 139us/sample - loss: 2.2706 - y1_output_loss: 0.4394 - y2_output_loss: 1.8141 - y1_output_root_mean_squared_error: 0.6660 - y2_output_root_mean_squared_error: 1.3517 - val_loss: 1.9504 - val_y1_output_loss: 0.3125 - val_y2_output_loss: 1.6003 - val_y1_output_root_mean_squared_error: 0.5532 - val_y2_output_root_mean_squared_error: 1.2823
# Epoch 118/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.0569 - y1_output_loss: 0.5243 - y2_output_loss: 1.5174 - y1_output_root_mean_squared_error: 0.7274 - y2_output_root_mean_squared_error: 1.2360 - val_loss: 1.6938 - val_y1_output_loss: 0.3378 - val_y2_output_loss: 1.3465 - val_y1_output_root_mean_squared_error: 0.5614 - val_y2_output_root_mean_squared_error: 1.1741
# Epoch 119/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.0756 - y1_output_loss: 0.4443 - y2_output_loss: 1.6239 - y1_output_root_mean_squared_error: 0.6660 - y2_output_root_mean_squared_error: 1.2775 - val_loss: 2.2948 - val_y1_output_loss: 0.9943 - val_y2_output_loss: 1.4401 - val_y1_output_root_mean_squared_error: 0.9517 - val_y2_output_root_mean_squared_error: 1.1786
# Epoch 120/500
# 614/614 [==============================] - 0s 188us/sample - loss: 1.6377 - y1_output_loss: 0.3852 - y2_output_loss: 1.2739 - y1_output_root_mean_squared_error: 0.6227 - y2_output_root_mean_squared_error: 1.1180 - val_loss: 2.8107 - val_y1_output_loss: 0.6068 - val_y2_output_loss: 2.1634 - val_y1_output_root_mean_squared_error: 0.7729 - val_y2_output_root_mean_squared_error: 1.4877
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.2888 - y1_output_loss: 0.1023 - y2_output_loss: 0.1863 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.4315 - val_loss: 0.6060 - val_y1_output_loss: 0.1686 - val_y2_output_loss: 0.4495 - val_y1_output_root_mean_squared_error: 0.3909 - val_y2_output_root_mean_squared_error: 0.6732
# Epoch 462/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.4018 - y1_output_loss: 0.1121 - y2_output_loss: 0.2968 - y1_output_root_mean_squared_error: 0.3318 - y2_output_root_mean_squared_error: 0.5401 - val_loss: 0.9678 - val_y1_output_loss: 0.2389 - val_y2_output_loss: 0.7331 - val_y1_output_root_mean_squared_error: 0.4737 - val_y2_output_root_mean_squared_error: 0.8622
# Epoch 463/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.6139 - y1_output_loss: 0.1406 - y2_output_loss: 0.4691 - y1_output_root_mean_squared_error: 0.3755 - y2_output_root_mean_squared_error: 0.6877 - val_loss: 0.7834 - val_y1_output_loss: 0.2474 - val_y2_output_loss: 0.5656 - val_y1_output_root_mean_squared_error: 0.4700 - val_y2_output_root_mean_squared_error: 0.7500
# Epoch 464/500
# 614/614 [==============================] - 0s 148us/sample - loss: 0.3648 - y1_output_loss: 0.1126 - y2_output_loss: 0.2553 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.5035 - val_loss: 0.8899 - val_y1_output_loss: 0.3127 - val_y2_output_loss: 0.5918 - val_y1_output_root_mean_squared_error: 0.5429 - val_y2_output_root_mean_squared_error: 0.7715
# Epoch 465/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3569 - y1_output_loss: 0.1221 - y2_output_loss: 0.2348 - y1_output_root_mean_squared_error: 0.3467 - y2_output_root_mean_squared_error: 0.4865 - val_loss: 0.9311 - val_y1_output_loss: 0.3470 - val_y2_output_loss: 0.6279 - val_y1_output_root_mean_squared_error: 0.5638 - val_y2_output_root_mean_squared_error: 0.7830
# Epoch 466/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.6133 - y1_output_loss: 0.1851 - y2_output_loss: 0.4236 - y1_output_root_mean_squared_error: 0.4312 - y2_output_root_mean_squared_error: 0.6537 - val_loss: 0.6358 - val_y1_output_loss: 0.1729 - val_y2_output_loss: 0.4635 - val_y1_output_root_mean_squared_error: 0.4057 - val_y2_output_root_mean_squared_error: 0.6864
# Epoch 467/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.3559 - y1_output_loss: 0.1261 - y2_output_loss: 0.2323 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.4813 - val_loss: 0.9512 - val_y1_output_loss: 0.2206 - val_y2_output_loss: 0.7274 - val_y1_output_root_mean_squared_error: 0.4551 - val_y2_output_root_mean_squared_error: 0.8626
# Epoch 468/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.7799 - y1_output_loss: 0.2066 - y2_output_loss: 0.5672 - y1_output_root_mean_squared_error: 0.4556 - y2_output_root_mean_squared_error: 0.7565 - val_loss: 0.6110 - val_y1_output_loss: 0.1808 - val_y2_output_loss: 0.4396 - val_y1_output_root_mean_squared_error: 0.4078 - val_y2_output_root_mean_squared_error: 0.6668
# Epoch 469/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.2897 - y1_output_loss: 0.1011 - y2_output_loss: 0.1945 - y1_output_root_mean_squared_error: 0.3180 - y2_output_root_mean_squared_error: 0.4342 - val_loss: 2.6146 - val_y1_output_loss: 0.4060 - val_y2_output_loss: 2.2286 - val_y1_output_root_mean_squared_error: 0.6192 - val_y2_output_root_mean_squared_error: 1.4937
# Epoch 470/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3375 - y1_output_loss: 0.1091 - y2_output_loss: 0.2267 - y1_output_root_mean_squared_error: 0.3317 - y2_output_root_mean_squared_error: 0.4769 - val_loss: 0.6295 - val_y1_output_loss: 0.1643 - val_y2_output_loss: 0.4760 - val_y1_output_root_mean_squared_error: 0.3876 - val_y2_output_root_mean_squared_error: 0.6923
# Epoch 471/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3109 - y1_output_loss: 0.1192 - y2_output_loss: 0.1976 - y1_output_root_mean_squared_error: 0.3431 - y2_output_root_mean_squared_error: 0.4395 - val_loss: 1.7372 - val_y1_output_loss: 0.2402 - val_y2_output_loss: 1.4926 - val_y1_output_root_mean_squared_error: 0.4742 - val_y2_output_root_mean_squared_error: 1.2297
# Epoch 472/500
# 614/614 [==============================] - 0s 175us/sample - loss: 0.4649 - y1_output_loss: 0.1181 - y2_output_loss: 0.3463 - y1_output_root_mean_squared_error: 0.3440 - y2_output_root_mean_squared_error: 0.5887 - val_loss: 0.8655 - val_y1_output_loss: 0.1946 - val_y2_output_loss: 0.6935 - val_y1_output_root_mean_squared_error: 0.4126 - val_y2_output_root_mean_squared_error: 0.8338
# Epoch 473/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.7148 - y1_output_loss: 0.1817 - y2_output_loss: 0.5273 - y1_output_root_mean_squared_error: 0.4280 - y2_output_root_mean_squared_error: 0.7291 - val_loss: 0.7875 - val_y1_output_loss: 0.1924 - val_y2_output_loss: 0.6136 - val_y1_output_root_mean_squared_error: 0.4170 - val_y2_output_root_mean_squared_error: 0.7833
# Epoch 474/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4046 - y1_output_loss: 0.1363 - y2_output_loss: 0.2653 - y1_output_root_mean_squared_error: 0.3704 - y2_output_root_mean_squared_error: 0.5171 - val_loss: 0.7068 - val_y1_output_loss: 0.1801 - val_y2_output_loss: 0.5377 - val_y1_output_root_mean_squared_error: 0.4086 - val_y2_output_root_mean_squared_error: 0.7347
# Epoch 475/500
# 614/614 [==============================] - 0s 152us/sample - loss: 0.2776 - y1_output_loss: 0.0966 - y2_output_loss: 0.1862 - y1_output_root_mean_squared_error: 0.3113 - y2_output_root_mean_squared_error: 0.4251 - val_loss: 1.0201 - val_y1_output_loss: 0.2429 - val_y2_output_loss: 0.7737 - val_y1_output_root_mean_squared_error: 0.4818 - val_y2_output_root_mean_squared_error: 0.8877
# Epoch 476/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2777 - y1_output_loss: 0.1134 - y2_output_loss: 0.1633 - y1_output_root_mean_squared_error: 0.3369 - y2_output_root_mean_squared_error: 0.4052 - val_loss: 0.7276 - val_y1_output_loss: 0.2402 - val_y2_output_loss: 0.5063 - val_y1_output_root_mean_squared_error: 0.4733 - val_y2_output_root_mean_squared_error: 0.7097
# Epoch 477/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3074 - y1_output_loss: 0.1142 - y2_output_loss: 0.1927 - y1_output_root_mean_squared_error: 0.3363 - y2_output_root_mean_squared_error: 0.4409 - val_loss: 0.6133 - val_y1_output_loss: 0.1598 - val_y2_output_loss: 0.4638 - val_y1_output_root_mean_squared_error: 0.3824 - val_y2_output_root_mean_squared_error: 0.6835
# Epoch 478/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.2950 - y1_output_loss: 0.1029 - y2_output_loss: 0.1920 - y1_output_root_mean_squared_error: 0.3211 - y2_output_root_mean_squared_error: 0.4381 - val_loss: 0.6066 - val_y1_output_loss: 0.1776 - val_y2_output_loss: 0.4455 - val_y1_output_root_mean_squared_error: 0.3979 - val_y2_output_root_mean_squared_error: 0.6696
# Epoch 479/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3229 - y1_output_loss: 0.1148 - y2_output_loss: 0.2103 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.4562 - val_loss: 0.8417 - val_y1_output_loss: 0.1958 - val_y2_output_loss: 0.6739 - val_y1_output_root_mean_squared_error: 0.4155 - val_y2_output_root_mean_squared_error: 0.8180
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3554 - y1_output_loss: 0.1152 - y2_output_loss: 0.2419 - y1_output_root_mean_squared_error: 0.3396 - y2_output_root_mean_squared_error: 0.4900 - val_loss: 0.7600 - val_y1_output_loss: 0.2149 - val_y2_output_loss: 0.5608 - val_y1_output_root_mean_squared_error: 0.4423 - val_y2_output_root_mean_squared_error: 0.7513
# Epoch 481/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3503 - y1_output_loss: 0.1171 - y2_output_loss: 0.2321 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4837 - val_loss: 0.6798 - val_y1_output_loss: 0.1827 - val_y2_output_loss: 0.4995 - val_y1_output_root_mean_squared_error: 0.4110 - val_y2_output_root_mean_squared_error: 0.7148
# Epoch 482/500
# 614/614 [==============================] - 0s 149us/sample - loss: 0.3919 - y1_output_loss: 0.1127 - y2_output_loss: 0.2760 - y1_output_root_mean_squared_error: 0.3369 - y2_output_root_mean_squared_error: 0.5276 - val_loss: 0.6433 - val_y1_output_loss: 0.1655 - val_y2_output_loss: 0.4874 - val_y1_output_root_mean_squared_error: 0.3866 - val_y2_output_root_mean_squared_error: 0.7027
# Epoch 483/500
# 614/614 [==============================] - 0s 145us/sample - loss: 0.5528 - y1_output_loss: 0.1591 - y2_output_loss: 0.3919 - y1_output_root_mean_squared_error: 0.4000 - y2_output_root_mean_squared_error: 0.6267 - val_loss: 0.9180 - val_y1_output_loss: 0.3244 - val_y2_output_loss: 0.6293 - val_y1_output_root_mean_squared_error: 0.5411 - val_y2_output_root_mean_squared_error: 0.7907
# Epoch 484/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4569 - y1_output_loss: 0.1255 - y2_output_loss: 0.3283 - y1_output_root_mean_squared_error: 0.3551 - y2_output_root_mean_squared_error: 0.5751 - val_loss: 0.6146 - val_y1_output_loss: 0.1695 - val_y2_output_loss: 0.4470 - val_y1_output_root_mean_squared_error: 0.3947 - val_y2_output_root_mean_squared_error: 0.6774
# Epoch 485/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.2850 - y1_output_loss: 0.1052 - y2_output_loss: 0.1808 - y1_output_root_mean_squared_error: 0.3233 - y2_output_root_mean_squared_error: 0.4249 - val_loss: 0.6827 - val_y1_output_loss: 0.2606 - val_y2_output_loss: 0.4635 - val_y1_output_root_mean_squared_error: 0.4794 - val_y2_output_root_mean_squared_error: 0.6729
# Epoch 486/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.5027 - y1_output_loss: 0.1596 - y2_output_loss: 0.3416 - y1_output_root_mean_squared_error: 0.4011 - y2_output_root_mean_squared_error: 0.5846 - val_loss: 0.8461 - val_y1_output_loss: 0.1729 - val_y2_output_loss: 0.6781 - val_y1_output_root_mean_squared_error: 0.3963 - val_y2_output_root_mean_squared_error: 0.8301
# Epoch 487/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.2864 - y1_output_loss: 0.1035 - y2_output_loss: 0.1834 - y1_output_root_mean_squared_error: 0.3195 - y2_output_root_mean_squared_error: 0.4294 - val_loss: 0.8531 - val_y1_output_loss: 0.3223 - val_y2_output_loss: 0.5808 - val_y1_output_root_mean_squared_error: 0.5404 - val_y2_output_root_mean_squared_error: 0.7490
# Epoch 488/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3597 - y1_output_loss: 0.1289 - y2_output_loss: 0.2357 - y1_output_root_mean_squared_error: 0.3578 - y2_output_root_mean_squared_error: 0.4813 - val_loss: 1.4121 - val_y1_output_loss: 0.3450 - val_y2_output_loss: 1.1012 - val_y1_output_root_mean_squared_error: 0.5678 - val_y2_output_root_mean_squared_error: 1.0439
# Epoch 489/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3858 - y1_output_loss: 0.1238 - y2_output_loss: 0.2681 - y1_output_root_mean_squared_error: 0.3487 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 1.0120 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 0.7587 - val_y1_output_root_mean_squared_error: 0.4947 - val_y2_output_root_mean_squared_error: 0.8760
# Epoch 490/500
# 614/614 [==============================] - 0s 142us/sample - loss: 1.2267 - y1_output_loss: 0.2670 - y2_output_loss: 0.9496 - y1_output_root_mean_squared_error: 0.5191 - y2_output_root_mean_squared_error: 0.9784 - val_loss: 0.6865 - val_y1_output_loss: 0.1647 - val_y2_output_loss: 0.5334 - val_y1_output_root_mean_squared_error: 0.3844 - val_y2_output_root_mean_squared_error: 0.7340
# Epoch 491/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3289 - y1_output_loss: 0.0962 - y2_output_loss: 0.2316 - y1_output_root_mean_squared_error: 0.3108 - y2_output_root_mean_squared_error: 0.4820 - val_loss: 0.6991 - val_y1_output_loss: 0.2641 - val_y2_output_loss: 0.4615 - val_y1_output_root_mean_squared_error: 0.4942 - val_y2_output_root_mean_squared_error: 0.6745
# Epoch 492/500
# 614/614 [==============================] - 0s 142us/sample - loss: 0.3649 - y1_output_loss: 0.1297 - y2_output_loss: 0.2326 - y1_output_root_mean_squared_error: 0.3617 - y2_output_root_mean_squared_error: 0.4838 - val_loss: 0.5890 - val_y1_output_loss: 0.1884 - val_y2_output_loss: 0.4257 - val_y1_output_root_mean_squared_error: 0.4046 - val_y2_output_root_mean_squared_error: 0.6522
# Epoch 493/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4056 - y1_output_loss: 0.1118 - y2_output_loss: 0.2946 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.5443 - val_loss: 0.7452 - val_y1_output_loss: 0.2661 - val_y2_output_loss: 0.5161 - val_y1_output_root_mean_squared_error: 0.4853 - val_y2_output_root_mean_squared_error: 0.7139
# Epoch 494/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3232 - y1_output_loss: 0.1143 - y2_output_loss: 0.2068 - y1_output_root_mean_squared_error: 0.3390 - y2_output_root_mean_squared_error: 0.4563 - val_loss: 0.5322 - val_y1_output_loss: 0.1533 - val_y2_output_loss: 0.3952 - val_y1_output_root_mean_squared_error: 0.3711 - val_y2_output_root_mean_squared_error: 0.6281
# Epoch 495/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2960 - y1_output_loss: 0.1096 - y2_output_loss: 0.1849 - y1_output_root_mean_squared_error: 0.3311 - y2_output_root_mean_squared_error: 0.4317 - val_loss: 0.5959 - val_y1_output_loss: 0.2077 - val_y2_output_loss: 0.4177 - val_y1_output_root_mean_squared_error: 0.4281 - val_y2_output_root_mean_squared_error: 0.6424
# Epoch 496/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.2653 - y1_output_loss: 0.0968 - y2_output_loss: 0.1675 - y1_output_root_mean_squared_error: 0.3106 - y2_output_root_mean_squared_error: 0.4109 - val_loss: 0.5609 - val_y1_output_loss: 0.1603 - val_y2_output_loss: 0.4148 - val_y1_output_root_mean_squared_error: 0.3793 - val_y2_output_root_mean_squared_error: 0.6457
# Epoch 497/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3137 - y1_output_loss: 0.1127 - y2_output_loss: 0.2042 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4492 - val_loss: 1.2861 - val_y1_output_loss: 0.4594 - val_y2_output_loss: 0.8837 - val_y1_output_root_mean_squared_error: 0.6470 - val_y2_output_root_mean_squared_error: 0.9314
# Epoch 498/500
# 614/614 [==============================] - 0s 144us/sample - loss: 0.2931 - y1_output_loss: 0.1106 - y2_output_loss: 0.1808 - y1_output_root_mean_squared_error: 0.3336 - y2_output_root_mean_squared_error: 0.4264 - val_loss: 0.5721 - val_y1_output_loss: 0.1551 - val_y2_output_loss: 0.4251 - val_y1_output_root_mean_squared_error: 0.3752 - val_y2_output_root_mean_squared_error: 0.6567
# Epoch 499/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3579 - y1_output_loss: 0.1254 - y2_output_loss: 0.2306 - y1_output_root_mean_squared_error: 0.3550 - y2_output_root_mean_squared_error: 0.4815 - val_loss: 0.6512 - val_y1_output_loss: 0.1891 - val_y2_output_loss: 0.4768 - val_y1_output_root_mean_squared_error: 0.4151 - val_y2_output_root_mean_squared_error: 0.6920
# Epoch 500/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4558 - y1_output_loss: 0.1194 - y2_output_loss: 0.3376 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.5799 - val_loss: 1.1392 - val_y1_output_loss: 0.2844 - val_y2_output_loss: 0.8863 - val_y1_output_root_mean_squared_error: 0.5092 - val_y2_output_root_mean_squared_error: 0.9380

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 45us/sample - loss: 1.1392 - y1_output_loss: 0.2612 - y2_output_loss: 0.8767 - y1_output_root_mean_squared_error: 0.5092 - y2_output_root_mean_squared_error: 0.9380
# Loss = 1.1391632030536603, Y1_loss = 0.2612024247646332, Y1_mse = 0.5091840028762817, Y2_loss = 0.8766709566116333, Y2_mse = 0.9380270838737488

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
